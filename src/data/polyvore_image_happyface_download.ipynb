# %% [markdown]
# Install modules if needed:

# %%
# !pip install datasets

# %%
from datasets import load_dataset
from huggingface_hub import login

# %% [markdown]
# ### Note:
#
# Add login token to the next cell, ask Ansh if in project

# %%
login(token='')

# %%
ds = load_dataset("Marqo/polyvore", split="data")
ds.save_to_disk("polyvore_dataset/hf_images")
# Out:
# ...
# Saving the dataset (6/6 shards): 100%|██████████| 94096/94096 [00:21<00:00, 4382.60 examples/s]
