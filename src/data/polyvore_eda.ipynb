# %% [markdown]
# # Polyvore Dataset EDA

# %% [markdown]
# ## 1. Setup

# %%
#import dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Combining Datasets:

# %%
df = pd.concat([pd.read_json(f"../../polyvore_dataset/{f}") for f in ["train_no_dup.json", "valid_no_dup.json", "test_no_dup.json"]], ignore_index=True)
df
# Out:
#                                                     name  views  \
# 0                                                 Casual   8743
# 1      Being a Vans shoe model with Luke. Idk about t...    188
# 2                    These Chanel bags is a bad habit .x    562
# 3                               Avenger/Supernatural prp   2613
# 4                                              Boho (39)     62
# ...                                                  ...    ...
# 21884                                            Casual|      8
# 21885                                             Casual  20192
# 21886                                       Winter White    338
# 21887                        Hot Ticket: Rihanna Concert  11891
# 21888                                       Street Style     98
#
#                                                    items  \
# 0      [{'index': 1, 'name': 'mock neck embroidery su...
# 1      [{'index': 1, 'name': 'nirvana distressed t-sh...
# ...
